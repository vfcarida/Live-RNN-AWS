# %% [markdown]
# # Rede Neural Recorrente (RNN)
#
# Neste notebook nós treinamos uma RNN em algumas músicas da Anitta. Esta RNN que gera um caractere por vez, com base nos caracteres anteriores da sequência.
#
# O código original da RNN foi escrito por por [vinhkhuc](https://gist.github.com/vinhkhuc/7ec5bf797308279dc587), baseado no código de Andrej Karpathy (atualmente diretor de IA da Tesla Motors).
# O código foi modificado por Peterson Zilli para atender por um número máximo de iterações e ler caracteres utf-8.
#
# Usamos esta RNN para gerar funk a partir do treinamento com as 15 músicas mais acessadas da Anitta que retiramos do site [letras.com.br](www.letras.com.br).
#
# As letras estão no arquivo 'anitta.txt'
#
# Vinicius F. Caridá & Amir Jalilifard

# %%
with open('anitta.txt', 'r', encoding='utf-8') as txt:
    print(txt.read(500))
# Out:
# Você prepara, mas não dispara
# Você repara, mas não encara
# Se acha o cara, mas não me para
# Tá cheio de maldade, mas não me encara
#
# Você já tá querendo e eu também
# Mas é cheio de história e de porém
# Virou covarde, tô com vontade
# Mas você tá demorando uma eternidade
#
# Se você não vem, eu vou botar pressão
# Não vou te esperar, tô cheia de opção
# Eu não sou mulher de aturar sermão
# Me encara, se prepara
# Que eu vou jogar bem na sua cara
#
# Bem na sua cara
# Eu vou rebolar bem na sua cara
# Bem na sua cara
# Hoje

# %% [markdown]
# Agora, usamos este texto para treinar a rede recorrente

# %%
"""
Vanilla Char-RNN using TensorFlow by Vinh Khuc (@knvinh).
Adapted from Karpathy's min-char-rnn.py
https://gist.github.com/karpathy/d4dee566867f8291f086
Requires tensorflow>=1.0
BSD License
"""
import random
import numpy as np
import tensorflow as tf

seed_value = 42
tf.set_random_seed(seed_value)
random.seed(seed_value)

def one_hot(v):
    return np.eye(vocab_size)[v]

# Data I/O
data = open('anitta.txt', 'r', encoding='utf-8').read()  # Use this source file as input for RNN
chars = sorted(list(set(data)))
data_size, vocab_size = len(data), len(chars)
print('Data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}

# Hyper-parameters
hidden_size   = 256  # hidden layer's size
seq_length    = 25   # number of steps to unroll
learning_rate = 1e-3

inputs     = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name="inputs")
targets    = tf.placeholder(shape=[None, vocab_size], dtype=tf.float32, name="targets")
init_state = tf.placeholder(shape=[1, hidden_size], dtype=tf.float32, name="state")

initializer = tf.random_normal_initializer(stddev=0.1)

with tf.variable_scope("RNN") as scope:
    hs_t = init_state
    ys = []
    for t, xs_t in enumerate(tf.split(inputs, seq_length, axis=0)):
        if t > 0: scope.reuse_variables()  # Reuse variables
        Wxh = tf.get_variable("Wxh", [vocab_size, hidden_size], initializer=initializer)
        Whh = tf.get_variable("Whh", [hidden_size, hidden_size], initializer=initializer)
        Why = tf.get_variable("Why", [hidden_size, vocab_size], initializer=initializer)
        bh  = tf.get_variable("bh", [hidden_size], initializer=initializer)
        by  = tf.get_variable("by", [vocab_size], initializer=initializer)

        hs_t = tf.tanh(tf.matmul(xs_t, Wxh) + tf.matmul(hs_t, Whh) + bh)
        ys_t = tf.matmul(hs_t, Why) + by
        ys.append(ys_t)

hprev = hs_t
output_softmax = tf.nn.softmax(ys[-1])  # Get softmax for sampling

outputs = tf.concat(ys, axis=0)
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=targets, logits=outputs))

# Minimizer
minimizer = tf.train.AdamOptimizer()
grads_and_vars = minimizer.compute_gradients(loss)

# Gradient clipping
grad_clipping = tf.constant(5.0, name="grad_clipping")
clipped_grads_and_vars = []
for grad, var in grads_and_vars:
    clipped_grad = tf.clip_by_value(grad, -grad_clipping, grad_clipping)
    clipped_grads_and_vars.append((clipped_grad, var))

# Gradient updates
updates = minimizer.apply_gradients(clipped_grads_and_vars)

# Session
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# Initial values
n, p = 0, 0
hprev_val = np.zeros([1, hidden_size])

while True:
    # Initialize
    if p + seq_length + 1 >= len(data) or n == 0:
        hprev_val = np.zeros([1, hidden_size])
        p = 0  # reset

    # Prepare inputs
    input_vals  = [char_to_ix[ch] for ch in data[p:p + seq_length]]
    target_vals = [char_to_ix[ch] for ch in data[p + 1:p + seq_length + 1]]

    input_vals  = one_hot(input_vals)
    target_vals = one_hot(target_vals)

    hprev_val, loss_val, _ = sess.run([hprev, loss, updates],
                                      feed_dict={inputs: input_vals,
                                                 targets: target_vals,
                                                 init_state: hprev_val})
    if n % 500 == 0:
        # Progress
        print('iter: %d, p: %d, loss: %f' % (n, p, loss_val))

        # Do sampling
        sample_length = 200
        start_ix      = random.randint(0, len(data) - seq_length)
        sample_seq_ix = [char_to_ix[ch] for ch in data[start_ix:start_ix + seq_length]]
        ixes          = []
        sample_prev_state_val = np.copy(hprev_val)

        for t in range(sample_length):
            sample_input_vals = one_hot(sample_seq_ix)
            sample_output_softmax_val, sample_prev_state_val = \
                sess.run([output_softmax, hprev],
                         feed_dict={inputs: sample_input_vals, init_state: sample_prev_state_val})

            ix = np.random.choice(range(vocab_size), p=sample_output_softmax_val.ravel())
            ixes.append(ix)
            sample_seq_ix = sample_seq_ix[1:] + [ix]

        txt = ''.join(ix_to_char[ix] for ix in ixes)
        print('----\n %s \n----\n' % (txt,))

    p += seq_length
    n += 1
# Out:
# Data has 7174 characters, 65 unique.
# WARNING:tensorflow:From C:\Users\vinicius\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-2-c4682ddfbf6f>:57: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# iter: 0, p: 0, loss: 4.652970
# ----
#  Pãô
# ébáu fpBVHárúáSéJJoo"ãa IpjuQSbxébJJdMg(CúIDôdJ"rq:átIVzvíUzAq(DÔ:M"CúoéçeTFáuxkf"xJpCê:zÔ çHUr:uHDNnsMlpovjjIbiP,uueeÔéDiéBMlzHíjã
#  ízáJrôÔn?vfDJNerkçfuauII"IxÔs
# eéRÔ,H?BMésgVcFçé(çoqÔEJíU"eV:L z
# ----
#
# iter: 500, p: 5350, loss: 3.267852
# ----
#  aedederm e Seua, tilrnci ,ola
# aa)e n eiévdaa eétae léaqsera uDiarlç Coie  eapen era hrdlu ,urodasei
# ri
# ri qrr sum e mer n eeleaveucdu
# dcenliQeer
# uulegirevlcv zjd
# na uenvp,lhqtur vSbfiharalrnc tvre m
# ----
#
# iter: 1000, p: 3550, loss: 2.557410
# ----
#   qoe Us:mouda numauo ru, mo Uua U eus enêrn
# V cunvLuãoudo terUn
#
# Uhr
# nuuardo, ho, ua Jhh pr
# Tendu  er ne, ve, ua,oMia
# em nia or ceu,,n
# nor vou
# mu dudavurSV h, su, queru, nVz uen nTeue, Vareue, voreu
# ----
#
# iter: 1500, p: 1750, loss: 2.566121
# ----
#  ra, ge ini vonh fãs
# vio, rigariiuqner
# nãosAaiê, do tãisissEa gao íuitariE
# DivarSereneãmel
# nommeãormente te eresManDóepdermp
# Ee lonr
# uem vhisaãta ainta,puitha
# DB bôãt
# Vão êião mu Empmoelnu, eigtÉu cam
# ----
#
# iter: 2000, p: 7100, loss: 2.355160
# ----
#  ra Ne na
# Lerqse eno eBomizoVM tuer euite pamei oete ou teide Be vocim e mao eim-i lue focom Msu to fompre melhe locar panminle jor eo queu, eó fa noA a m oe o foa de secarêe menaeme:u m mocem le eicob
# ----
#
# iter: 2500, p: 5300, loss: 2.397562
# ----
#
# a
# Se viua onla eu quer, pla e, elar ve
# dl, luidh
# Eu nô gonte dento ere caltam csro , qua merraar
# Mula mocar
# lena Ciusa  u vouberare, eu queroucimubosu
#  u f co
#
# Eunq er
# caito ao succo
# ela é , nha nou
# ----
#
# iter: 3000, p: 3500, loss: 1.388788
# ----
#  o cou da doirador
# E óe ção tera
#
# Eir
# Se pra
# Eua, re voe, Hoa ta e éo
# ardoceran
# Dem
#
# O vada
# Enda pado
# Op a gie ar po disa
#
# Var ba do áia
# Do e é ssehop auaroe
#
# o paa veu voch
# quh, uha ue paebivao erar d
# ----
#
# iter: 3500, p: 1700, loss: 2.666428
# ----
#  tr, nem nha Eradem não anta meltera
# Ser mas
# Eu fuvor
#
# Eu jesse, am ntãonMão sulao, nu talesaó mão oe vocêié fuvan intelar
# Mimpremo Euatoss
#
# Bem ntpsxtemotm se surdo fistorprna su te pão sott
#
# Tsmgoo m
# ----
#
# iter: 4000, p: 7050, loss: 1.552294
# ----
#  ler sur ou cevre co pai é s frir
# O O ta quztita cancar vage lue sithe que xa frenda mesmeu facê: se sim didi fre muinhe pa vom
#
# E mem,r
# A querse ta car, má
# Uão ma maz rm mre cossfra
# Rdo cem nham tido
# ----
#
# iter: 4500, p: 5250, loss: 1.915155
# ----
#  octen, oua parfeca
#
# Qua cema bem nhatu
#
# Eu govee, eselte e monte poba vina enlo casA oi erena éela
# Mejo vida, te vindica
#
# Éão é lanta lera, nha becar, no bobaiv, el, pina bocê
# Se eu tô bom dr, uinde n
# ----
#
# iter: 5000, p: 3450, loss: 0.215192
# ----
#   ssei vor voo jolta por antir, eh, eha mha hocar
# To du vii vom lda, fão quavo cam vamca
# Eue vou o cêes veinque maliita dem chero prdprangoper você cenanta que doao te el vidar var nou camria dais
# é tã
# ----
#
# iter: 5500, p: 1650, loss: 2.425748
# ----
#  ó ae çoctmo ém ficosmassa euare, oma acomca seu tompoutera, ento ta
# Natê
# Des nevouprna
#
# Panha arotde arpamé demelem eltprarouão da ceda
#
# Eumvouprocarur,ou temar semola ssa marsse vorem oivouprro
# Se po
# ----
#
# iter: 6000, p: 7000, loss: 1.836153
# ----
#
# Ve jamo e meoro tmelo
# Eu gena
# E micha você
#
# Lomar ela
# Snso aloucar
# O eue mo que te co e tim
# Prola mem que je te pot vem querfro e fhito a ssmbo
# o meras no  eucar o beboo da mco fe dor
# E em epa
# Sa vii
# ----
#
# iter: 6500, p: 5200, loss: 2.083967
# ----
#  oca
# Se e ver caja
# Quenca vever, e pem prebo de mande a mena é louca
#
# Essa minha mina não ei que é no de jera ridi ue e voch
#
# Que bola
# cabua mene que quentereMa ponquit, mindente finmija belo feinque e
# ----
#
# iter: 7000, p: 3400, loss: 1.072202
# ----
#  cana ses bem na selecar
# Dabertime avola
# Que ver
# Hvondebem nestar
#
# Vem vic, pona vir
# São temtdanma
#
# E pre ancanardeda
# Não
# se prasela mnde me postare
# Vom sinterare orantera pra vontaro
# Er bocqua que,
# El
# ----
#
# iter: 7500, p: 1600, loss: 2.036503
# ----
#
# Bem o feue fopto ba jeito e vobçta
# Eu vousconto sto porenttarore mo elassmossso cespar o ge a paro pra messarendo stum ne oocção
#
# Querotarem lha oocom mog
# do que su querta tode e te o amatas mis quem
# ----
#
# iter: 8000, p: 6950, loss: 1.285914
# ----
#  vir, querorco te que daze, com a gorar
# Pomassso cante cê bo ta panande parplia
#
# Eu momoc mm roca vei o temprra
# E aem
# o tembolo
# Pra uo po elmei pom prelo sue oncamerade pro mro, fuz quemorda
# Noitaruldo
# ----
#
# iter: 8500, p: 5150, loss: 0.404757
# ----
#  emes quino moica
# Se eu tô cos jrio, eu pli que oindidar jo cariija baido e
#
# Uato trabalanVacer pom a uinabei que vecê nosqe coraçinoa emejarela
# Vadasinda
# Sura ano ée deinla ca, mão dereite pama
# Vavana
# ----
#
# iter: 9000, p: 3350, loss: 0.481098
# ----
#  a
# Som noravo vou tizar
# Matese empteja
# Vee cossssom
# Hitma me toverda, tala
# Eutatm), anvocê teu justa pras u ter quera que vae malhaS a pssache te savoca, anço gem na nuem
# mo micar
#
# Em te ocara
#
# Pomprre
# ----
#
# iter: 9500, p: 1550, loss: 0.899345
# ----
#  na suu care), de eter vom fizer se jomolo var nãopêa mempra vait
# Qu mou deuam e mpraico de anvo eu sem ner possamprdar
#
# Mas se seu que fazem
#
# ue memeso nesto cre temeso mão bonte elme te desenco te pr
# ----
#
# iter: 10000, p: 6900, loss: 1.340096
# ----
#
# Terachepora
# Euer, eu mam lom cos,dm nu ssmola
# Se dasra
# E tundo pelavo nco te cem licar
# Spara
# Sem charo
# Mes ala
# Bá crr, um geuca pepa
# Mandojar
# Vam re você
#
# Teo aurtocar bem r emesso dudr
# Mas orço Te m
# ----
#
# iter: 10500, p: 5100, loss: 0.084051
# ----
#  ir
# E, e você, eu e você
#
# A sinhe vide e squelecada
# Que vouê sei aqua vinda, faim, me eu bima
# A manço ramandedea som é lhuir
# Moss utene domeço
#
# Sima je jadejo te fa desaa que te daçeja tar ao tô bola m
# ----
#
# iter: 11000, p: 3300, loss: 1.047555
# ----
#  jo dasplha me nca sia cimpção
# Eltade sóbeche co
# parimar lher cim
# E ambé fazem du você
# Ebenvo e afrite dessta
# Mo, não cure visi m irt do peseltadi
# Tem umpric
#
# stint rrabom, checor
# Eu tô bocar e cossíqu
# ----
#
# iter: 11500, p: 1500, loss: 1.116354
# ----
#   verfa, envar bem ta sua cara
# Se mssa te para
# Você repdeterte peltore te do, eu var
#
# Bem na sua cara
# Se echado eu mau jo am via beisar senhão de enta
# é mera luar ue vii am seu a menta bampa contar amo
# ----
#
# iter: 12000, p: 6850, loss: 1.388283
# ----
#  ar ndo provare, las nocamo ara é dara
# Sem chnco nisanho to qua vela
# Pur vola cadas amharaz
# renco posta Janda de dirando, Jonta do a voa brila na a anda
# Que ter o raz rizerento veu joganta, tinca venhe
# ----
#
# iter: 12500, p: 5050, loss: 0.069853
# ----
#  uer
# Voih, essmilado, ela quer beijo
# no bola
# Se eu tô bolada, ela quero ela é baigo que é fem
#
# E éanomemante oute aoso vavej favolar
# Vas aô evacheno oelau
#
# E ela quendo dadssado mededar
#
# Ele ou vou ala
# ----
#
# iter: 13000, p: 3250, loss: 1.251046
# ----
#  ere eutvocê
#
# Linda, livo o sede centocanquertangono que eu tié fazera comaise a bemalhada melgemagarou coutolham o curminhaso
# Te vicê
# Deixa poda vadi
# Vela é o coragando seu você
# Eu nou você
# Se xasso v
# ----
#
# iter: 13500, p: 1450, loss: 1.036454
# ----
#  ente ser la que onfe pra ura, tas não me pcaa o tenta
# Mas a beia
# Es ascara, me bru concante ver, eu vou botar pressão
# Eá encor, a senvocê, ela é aprapara
# Qua enavoa jenhé te par bende pe fazera, sea c
# ----
#
# iter: 14000, p: 6800, loss: 1.378381
# ----
#
# Te dar: Bem dia
# Destr ie te vocté a ler
# E amar
# Nu vol ssar volhajre a trndo nola
# VaecértRoseu lo ta centera
# Mab mão, lua no que mardé (ê quero com você te tarasose elocomancada
# Mes brilo que é cam
# Eu
# ----
#
# iter: 14500, p: 5000, loss: 0.088952
# ----
#  eje
# Nu manhace
#
# E vaijo
# Qum nosso de melacom na sua cara)
#
# Bem nco todija ma fazer me tem
# Vareiso me va, jo, is a vente sa a veijo
#
# Qua eu quero fimo sua cera você soumo a me ecsepe vor assir
# Por no c
# ----
# iter: 15000, p: 3200, loss: 0.616960
# ----
#
# Uhassom de nover beijo não s você vai
#
# E aissandede e focande
#
# Eu scorar se eucompís aque ses fuita nta gisedo poltivincer o aisa vei tasbrinco
#
# Te pra sabala
# Bem vaisse veinta
# Que eu vou dider um ou
# ----
#
# iter: 15500, p: 1400, loss: 1.026774
# ----
#  prasirande eu paiboda dido er va bem prrpar de a senter, eta o o para
# Eu vou a gerepra a mapreprra, mespno audo
#
# Pora quer ve jai ancampram
#
# É que eu feu se ador
#
# Eu veu par a pra vei ar, tea me a ven
# ----
#
# iter: 16000, p: 6750, loss: 0.491797
# ----
#  u vei tô bela
# É Ôou você vadçda
# ReJá cão é cunte e che es a milhe anta
# Veida :uBte te ancortu me de ginta
# Não se a
# Vende Ctocê pro eumreitor
# Não seu Ila
# PVada Cle vai smid
# Selhu olner pa pre ser bor
# S
# ----
#
# iter: 16500, p: 4950, loss: 0.013801
# ----
#  er no anoitecer, amanhecaa e couta beija que é feico nissio, ola cinde é tamisa do aista eiti que eu tasha chavila que encom mis elto te beia
# Eu cim fento qui ma nla ger aqui
#
# E gunte ei que e eite en
# ----
#
# iter: 17000, p: 3150, loss: 0.477946
# ----
#  endesso ver de você que soila e mprase até tugda essa ver aqumala car
#
# Eu vou para tera vidida de vocêdindas
# Tão que sandase aosvocê quene teser eu vou qle esse carana tasque ser assinteracorantra a p
# ----
#
# iter: 17500, p: 1350, loss: 0.783216
# ----
#
# Queno e nero e a eua eua
# Eu a vacNeinar
# Turo, eu vou reboe
#
# Bem
#
# Vem você pastara, mas não me pra sompara
# Vamin, eu vim sse jo penemagento par eu ta er pra vodca pesa eturagr,pereu de desena caite at
# ----
#
# iter: 18000, p: 6700, loss: 0.700174
# ----
#   aúfoca, ela do fe tenes ancan
# Ré liz r cem o combr
# Semo licar,
# Mes ar paro a tre mece jasmi ara noa, eue
#
# Vovor ndossa jer
# U Jofaçi
# Tu vo ê ano ara
# Elte ero não fei
# E as quela pro comtam se faz é chi
# ----
#
# iter: 18500, p: 4900, loss: 0.114963
# ----
#  não me elte o eme elaso rldi
#
# Eltu o loita cara do que você
#
# A gente sabe vivar, o quinse re tina é lina é louca
# Quando eu tô e lia e de é ndeda de ui,
# Tua nte aisa lão hegebaina maiss faço pude jo el
# ----
#
# iter: 19000, p: 3100, loss: 0.386328
# ----
#  a carevagasme me em quafa tem cer bem que a que vavessa que e vem
# Elada m corsa você qua esseleco possívelo
# E pgalm), pessogena
#
# Qe você sabmela
# Ele vou Alldarr
# Qum que var aque sor a mispar ou vavoc
# ----
#
# iter: 19500, p: 1300, loss: 0.284108
# ----
#  r a me ritarar ma dochegen e erecamara luacara, sa vicar
#
# Quma rua eu vou jogar brm na sua cara
#
# Bem na sua cara
#
# Su sei que u seu de nistara Bom de nhe mer a vricu siaro que e eu não que eu vou a tev
# ----
#
# iter: 20000, p: 6650, loss: 0.073257
# ----
#  der, uloco da azeja me veindo suquir
#
# Vem ne auotê o preco anda pla Eucrate
# Me auo
# A mei o têm no fuit, e sso nema
# Alna belgendo procrndi
# C posso dempar
# Eu e vala,
# Você er
#
# Se alhao a bruçr
# A mo bela
#
# ----
#
# iter: 20500, p: 4850, loss: 0.501502
# ----
#  ção
#
# Que o meu tem tá lismo
# Mao tem ta safe te camintão
# Te ei você
# Daim é raila
#
# E eu meu
# Eu movela
# Que eu vimbém
#
# Vem lejja envocê que é nemjo pode tadi que eu som
#
# Veino nelia e meito que eijo me de
# ----
#
# iter: 21000, p: 3050, loss: 0.724733
# ----
#  mina cur
# Ue vivo que sse am de miu fei que squ que s e porana sua que ala mitrela me gostamim
#
# El bé a meuta pra mimil
# Strr ve vo, jebtivar canto pem ta sufrite lessa vem ta dia ta pa, leve e smeleu f
# ----
#
# iter: 21500, p: 1250, loss: 0.175869
# ----
#  sua cara
# Bem na sua cara
#
# Bam na que mera
# Hoja eu vou jogar e mentr
# Tim
#
# Quer o merta dim meg par
# Se der nar
# Saro a a ameiraprrou me amprepara
# Bet na suancara
#
# Cheguai
# Tô rra beijar na boda
# E que e ar
# ----
#
# iter: 22000, p: 6600, loss: 0.026622
# ----
#   tebe fem
# Se eu tinta, nlo cantoc de ple mão
# Se ecora
# C
# , uinde linha cando is fizer ber, co minde
# Se dur é bemali
#
# Pe voltina
#
# Tunha pera é ora quecendeja de valesterOs o cora sa fave a mo faz
# Emesta
# ----
#
# iter: 22500, p: 4800, loss: 0.116790
# ----
#  sudo a me gentece foete uor
# Pina s atindo
# Não vou meu
# Você te eu tô com frio, ela tira a minha roupa
# Louca pesmeija
# Quando eu tô bolado, ela quer beijo na boca
# Se eu tô com frio, ela tida é linha dous
# ----
#
# iter: 23000, p: 3000, loss: 0.411352
# ----
#   elte em sei pra mas de amacafaz spre você passirado que eu vou plear, ets quelsa te cassa eu vou poger orê que seidacer gum quere enrreiss a sua diba ve disse messca
# Eu do qum é fia, sté se centente
# ----
#
# iter: 23500, p: 1200, loss: 0.162670
# ----
#   amoa bemalando em pra irarprestra ara deua rebomerar, pada, eu eisea temasae vio se leica, elavei de reu feita dea cera
# Ne ara eraderasera se arara até cara vou jogar presso ala, eu te vim dazura can
# ----
#
# iter: 24000, p: 6550, loss: 0.085521
# ----
#  E se vi deido quinoo fraco
# Menhada
# Tum na cuaderego que você
#
# Eu que que o anda de eu louca
# podo dilada, nls gão
# O sourA a
# Masta
# Jo quilo ba dimar
#
# Ele cuo noma
# Semosaí
# O mer
# ço
# Te dida go bem lheinte
# ----
#
# iter: 24500, p: 4750, loss: 0.150893
# ----
#  a soa cabei qoi sebe que cuitaje, ua, te
# É ela é mo te disse jemo e fis min
# E pra voca
# Na gaste cara doda que eu fui
#
# E euô e atar nca sia
# Ente er até boca se aca, a me nindo u tem de beu
# Ete bendaa t
# ----
#
# iter: 25000, p: 2950, loss: 0.332056
# ----
#   rtao se vol jor nches de moltam
# A contide dissa vida cor Uquelocortanos mente vinsso leuco anomina sua cara vou jogar bem na sua curapassssam
# Vaco que vou pandicur a boca
#
# Eu veu cobrizer, covaco pos
# ----
#
# iter: 25500, p: 1150, loss: 0.473488
# ----
#   suh, ras
# Se vorê lua, rua, tua nãora doro vo mim der, eu vou qutada
# Beg nher vacê tam nheterema  ta feita eu tavor aqua ce mitar
# Tá tam é chiro cernar
#
# Bem na sua cara
#
# Cheguei
# Tô você na bolta no qu
# ----
#
# iter: 26000, p: 6500, loss: 0.065745
# ----
#  lta
# EQ, umo comporco temo seijo
# Masuer, boma
# Te bom dancade
#
# Voi que cara
# V mo aeço perta deda dossube
#
# Vaga menda bellade, continta
# Nos você não vam sa daalua
#
# Quas ou fectidado, nha é dasa, tem você
# ----
#
# iter: 26500, p: 4700, loss: 0.197621
# ----
#  ass tata é ro eu tô com o ino cendole o que seja ne nca ser a ginde e você sabe que eu casto cortidade
#
# Vamina de covar
# Par a minte to ue eur peraça, na eu tem dazeliz o ou na bendo tatu
# Dendudo a se
# ----
#
# iter: 27000, p: 2900, loss: 0.185736
# ----
#  as seu quero eu qu vou vovar
# PQidida gurto ssa vosmam dev te de casir
# Serdas são prasor
#
# Que ago mer a émo nura atum ra bupra música
# Elendoro que elhera plharh, mespo alha a gunto
# Mas u sso pesso tão
# ----
#
# iter: 27500, p: 1100, loss: 0.142315
# ----
#  cara, eu prazer, te asa, sua ceuaE, eu vou alinhar
# Ber não
# Chogarde atornarar
# Bem na sua cara
#
# Cheguei
# Tô proca pera tó quenderde encontrde prra e era cernver
#
# Chs eralesar di do cheiro a vimor, m pre
# ----
#
# iter: 28000, p: 6450, loss: 0.604847
# ----
#  eu tô comin
# Velaco, euco teinoo do centora e você
#
# Lem trliso de cadelo ta galaço
# Aão pravia do Nuz que de de didevo lo centere a
# Aido a ela
# Elade turnção
# E pas cobar
#
# E sai que arande a vom danÉ pard
# ----
#
# iter: 28500, p: 4650, loss: 0.549424
# ----
#   apreija de eu quando eu tô bolado, ela quer beijo na bmida eu enhistar a é mor
# Site e eu canto prre
# le você nasse acarando par é mana é a rarija pre casseger
# E não me ende ela é eu tá diseda ve am nl
# ----
#
# iter: 29000, p: 2850, loss: 0.451817
# ----
#  ua conta posfater pa to de eis
# Você disse vivpreu tivapota da do se ene bolla
# Eu vos sou porticoranto seu euro cra irdade de você que sei porta ura boca, ela sua e eu vau asoi se meu de ale me de só r
# ----
#
# iter: 29500, p: 1050, loss: 0.289863
# ----
#  ucrnho posto de arcafei ar ve com elaze
# Ao fez que a mepre, eua coração que podelaze
# Eu gante centitar, lhareldo Ou e ver viche bem tanharundora
#
# Pere de mitar
# P
# Varmo ela é limme de mprra pescheite e
# ----
#
# iter: 30000, p: 6400, loss: 0.713349
# ----
#  aí, ela
# Passar lolha de vi asta eu tô linde, tlo no que saja
# Nasda, à vaca pora
#
# O tindo
# Tu quero dou bocaitada, ulo quero e caita que sonla
# Lasdar
# Te dei se daze
#
# Sereu tochita quentardade de u com v
# ----
#
# iter: 30500, p: 4600, loss: 0.402309
# ----
#  noitecer, no ela
# É , nte sub, ém
# u veitrona não re festa um, nha u para é sengandede
#
# Ele é emalhado, mas e vielei fazes nha pela gebaça, laté que te dazinhe min
#
# E ter
# Po pra boca
# Liuda, lovande eu t
# ----
#
# iter: 31000, p: 2800, loss: 0.955754
# ----
#  ito o ssa meu pole tudo e ge você
#
# Te você
# Dabaida boca
# A nesanhechaco porpo moss
# E elagiso ne você
# Desa eu vovbrora do vim anconte vo meu não me pra mida fiio o a divadi
# Mai a vonta boca até dom mum
# ----
# iter: 31500, p: 1000, loss: 0.508186
# ----
#   acha o cara, mas não de pera Bemelheruré e conto prr entarer
# Vom você
#
# Lembro que elazer
# Ques amoreu teraremar
# O asur perto de gudas
# Te hni que jai a voctinha
# Te eucorara, ne muereu te dezera, ne cin
# ----
#
# iter: 32000, p: 6350, loss: 0.836242
# ----
#  sorta (o acorela
#
# Quha míCo te diz dico tra chegir
# Domor você, eu vov isa e volça e minharr
# Tengente suantãolm
#
# Uão colta procê ntade
# Te gar elha dilavo pode afri ar
# Da alo mem cora inag ão bem poro l
# ----
#
# iter: 32500, p: 4550, loss: 0.625077
# ----
#  pra mina belto tem fuito exa conquisando
# Nat ate serido nm boca
# Dei a m
# Cireje tamina nar ou te tirea tem, não vol, pas
# Tudi , penconemo por a mir
#
# Ene beijo tinha codo dim, não vali
# Eumin, eu vou faz
# ----
#
# iter: 33000, p: 2750, loss: 0.352435
# ----
#  cando
# Te deito o pempre complicara
# Elo que éndianrerar, orarmida cara
#
# Você preporto Ais eua
# Eu cina eu vou conta bor inatr
# Ais a volta
# Eu disse: Já vou feito pra te dara
# Eu golta
# Eu gixa des pra noca
# ----
#
# iter: 33500, p: 950, loss: 0.260073
# ----
#  ge er veumio, eu vou botarde, tô comela mairpois queneres razer nda parzeu vou jegeite o leu dar
#
# Eu veu tate derando de untor vinhar de enterar
#
# Vúmbém
# Queso e maissadesostello
#
# Eu vou doande elisent
# ----
#
# iter: 34000, p: 6300, loss: 0.381244
# ----
#  greixa
#
# Eu vicê
# Eundo e da sua
# Nãe ve vepreaca
#
#
# Eu tado a é car
# Sumanhido
#
# Tão bela, funcorando
#
# Elo caz é cando é mumpur
# T deré dea te éur no decoste e fom
#
# Tho bempate
# Se a minha voca
# AT aque dasmi
# ----
#
# iter: 34500, p: 4500, loss: 0.423733
# ----
#   ela é lizes ó amola
#
# Eu vou fazer vo ê me vinde: cem o fem
# Eu a somadirar
# Dar bei
# Eu não sor
# Eu vão que você é gósto costi amoitheer, eu vou joitade
# Chega, encosta em mim
# Hoje eu quero e posto ou gis
# ----
#
# iter: 35000, p: 2700, loss: 1.064323
# ----
#   boca
#
# Linha, lissão meu melacomonte ora irago
# Tu canto go meuma
# Você pripara
# Que sua cobeivo canu a rassso descomprrca peluper u o quispo plivocendo ono é ssis am mou squis
# Eu tô bolado, ela é elver
#
# ----
#
# iter: 35500, p: 900, loss: 0.141717
# ----
#   soum, pra elado, e contader vai amompirar
# Não er eu tô bom de ao liocar ber eu vai bava vai sag e eserré, ee vintar de vichemelo
# Per te e ver des quereleitralo, ur, uhago)
#
# E você párazeum quero ena
# ----
#
# iter: 36000, p: 6250, loss: 0.561662
# ----
#  r a cana
# Mino razuda, liu
#
# E e a lovida pode gave cardelta
# J na quelsabra ce temo armbun,, ela tadida
#
# Qua a linhe tado po façinar o ardo jarta (aseja, façm
# Mas ser certinha mudo de cada
# Bem na sua ca
# ----
#
# iter: 36500, p: 4450, loss: 0.760318
# ----
#  Dando pravião
# Mim aldo
#
# Es beijo na boca
# Se eu tô com frio, ela, valde
# E temo cão veda
# A per meu
# E per mcim
#
# Elgente em fica
# Eu ga, lsuatr
#
# Vocanencada
# Se nco pisserera
#
# O paneles frido
# Mespar
# Que age
# ----
#
# iter: 37000, p: 2650, loss: 0.557731
# ----
#
# Mua cinassoutmmino seu misa sua sie eu fi pesta mibadabo
# Bom duanhu dais do que mere seste linde te eucontra prostão me vessemeixa empoltarapde o vei assim
# Dentra o meite de é cempontodo
#
# E você leuc
# ----
#
# iter: 37500, p: 850, loss: 0.274032
# ----
#  Vai te levar a mua, tua poe a ve ceinTão aemado e eu te bole
# Eu tô colade, sebremes a de aim
# Meva e pelar
#
# Que e e te em "ais,
# Sim vede iu aivar, e vene, out: ver
# Tecana
# Te cêem neragoltande vachara
# B
# ----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c4682ddfbf6f> in <module>
#      96                                       feed_dict={inputs: input_vals,
#      97                                                  targets: target_vals,
# ---> 98                                                  init_state: hprev_val})
#      99     if n % 500 == 0:
#     100         # Progress
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
